# %% [markdown]
# # JSS Experiment Moving Account User

# %%
# %%bash
# ./execute-observation.sh workloads/account-browser.yaml
# Out:
# [info] Automatic mode, workload driver is
# [info] --------------------------------------------------------------------
# [info] account-browser workloads/account-browser.yaml
# [info] --------------------------------------------------------------------
# [info] Stopping collector ...
# [info] done
#
# [info] Cleaning data
# [info] Deploying experiment...
# [info] Start collector
# 2018-06-25 18:44:28 ERROR TCPController - Could not parse port for the TCPController, deactivating this option. Received string was:
# [info] Automatic mode, workload driver is workloads/account-browser.yaml
# [info] Stopping existing distributed jpetstore instances ...
# [info] done
# [info] Start jpetstore
# a771e6f12ccc576368147317dc8320b61e3032ce3a56b764c3c8d281306c5f3d
# 3fef3f30c513db9f71e75dc9aec53f6c8a473a8cf7e84047ee1f01b0618ded6a
# 4c53947a346c27eec7df8c2c71c0a79706c34ac5da3c7b9111f8bdf6b4bb37ee
# a936e4895e9ce34b473403e368d59d9dea423245d6002575df083abb66ec380a
# ...

# %%
# %%bash
#
# for I in `ls data` ; do
#     ./execute-kieker-trace-analysis.sh $I
# done
# Out:
# 19:01:57,130 |-INFO in ch.qos.logback.classic.LoggerContext[default] - Could NOT find resource [logback.groovy]
# 19:01:57,130 |-INFO in ch.qos.logback.classic.LoggerContext[default] - Could NOT find resource [logback-test.xml]
# 19:01:57,130 |-INFO in ch.qos.logback.classic.LoggerContext[default] - Found resource [logback.xml] at [jar:file:/home/reiner/Projects/iObserve/experiments/tools/kieker-1.14-SNAPSHOT/lib/teetime-3.0-20161128.194027-256-jar-with-dependencies.jar!/logback.xml]
# 19:01:57,143 |-INFO in ch.qos.logback.core.joran.spi.ConfigurationWatchList@77468bd9 - URL [jar:file:/home/reiner/Projects/iObserve/experiments/tools/kieker-1.14-SNAPSHOT/lib/teetime-3.0-20161128.194027-256-jar-with-dependencies.jar!/logback.xml] is not of type file
# 19:01:57,174 |-INFO in ch.qos.logback.classic.joran.action.ConfigurationAction - debug attribute not set
# ...

# %% [markdown]
# <img src="analysis/aggregatedDeploymentCallTree.svg"/>
# <img src="analysis/assemblyComponentDependencyGraph.svg"/>
# <img src="analysis/containerDependencyGraph.svg"/>
# <img src="analysis/deploymentComponentDependencyGraph.svg"/>
