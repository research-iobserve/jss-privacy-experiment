# %% [markdown]
# # JSS Experiment Moving Account User

# %%
# %load config
################
# directories
# data location
TOOLS_DIR="$BASE_DIR/../tools"
DATA_DIR="$BASE_DIR/data"
FIXED_DIR="$BASE_DIR/fixed"
PCM_DIR="$BASE_DIR/pcm"
DB_DIR="$BASE_DIR/db"

# analysis results
RESULT_DIR="$BASE_DIR/results"

# docker repositoriy
DOCKER_REPO="blade1.se.internal:5000"

# logger IP
LOGGER=192.168.48.213

##############
## executables

# iobserve analysis
ANALYSIS="$TOOLS_DIR/analysis-0.0.3-SNAPSHOT/bin/analysis"

# workload driver
WORKLOAD_RUNNER=$TOOLS_DIR/selenium-experiment-workloads-1.0/bin/selenium-experiment-workloads

# webdriver
WEB_DRIVER="$TOOLS_DIR/chromedriver"

# collector
COLLECTOR="$TOOLS_DIR/collector-0.0.3-SNAPSHOT/bin/collector"

# end

# %%
# %load log4j.cfg
# Root logger option
log4j.rootLogger=INFO, stdout
log4j.rootLogger=ERROR, stdout
#log4j.rootLogger=DEBUG, stdout

# Direct log messages to stdout
log4j.appender.stdout=org.apache.log4j.ConsoleAppender
log4j.appender.stdout.Target=System.out
log4j.appender.stdout.layout=org.apache.log4j.PatternLayout
log4j.appender.stdout.layout.ConversionPattern=%d{yyyy-MM-dd HH:mm:ss} %-5p %c{1} - %m%n

# %%
# %%bash
# ./execute-observation.sh workloads/account-browser.yaml
# Out:
# [info] Automatic mode, workload driver is
# [info] --------------------------------------------------------------------
# [info]  workloads/account-browser.yaml
# [info] --------------------------------------------------------------------
# [info] Stopping collector ...
# [info] done
#
# [info] Cleaning data
# [info] Deploying experiment...
# [info] Start collector
# 2018-06-25 18:29:54 DEBUG AbstractServiceMain - Collector
# 2018-06-25 18:29:54 DEBUG DataDumpStage:DataDumpStage-0 - numOpenedInputPorts (inc): 1
# 2018-06-25 18:29:54 DEBUG DataDumpStage - Configuration complete.
# 2018-06-25 18:29:54 ERROR TCPController - Could not parse port for the TCPController, deactivating this option. Received string was:
# 2018-06-25 18:29:54 DEBUG WriterController - Initializing Writer Controller
# 2018-06-25 18:29:54 INFO  StateController - Enabling monitoring
# 2018-06-25 18:29:54 DEBUG MonitoringWriterThread - kieker.monitoring.writer.MonitoringWriterThread is running.
# ...
